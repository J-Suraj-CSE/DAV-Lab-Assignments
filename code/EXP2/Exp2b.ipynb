# %%
import os
print(os.getcwd())
# Out:
# D:\DAV LAB

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())
print(df.tail())
# Out:
#       Name  Age Department  Marks
# 0    Alice   20        CSE     85
# 1      Bob   21        ECE     78
# 2  Charlie   22         IT     92
# 3    David   20        CSE     88
# 4      Eva   21        EEE     81
#     Name  Age Department  Marks
# 3  David   20        CSE     88
# 4    Eva   21        EEE     81
# 5  Frank   22       MECH     75
# 6  Grace   20        CSE     95
# 7  Henry   21        ECE     80

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("data.csv")

# Display first and last rows
print("First 5 rows:\n", df.head())
print("\nLast 5 rows:\n", df.tail())

# Dataset information
print("\nDataset Info:")
df.info()

# Summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

# Create a new column
df["Double_Marks"] = df["Marks"] * 2

print("\nNew Column:")
print(df)

# Series operations
series = df["Marks"]
print("\nMarks + 10")
print(series + 10)

# Filter rows
filtered_df = df[(df["Marks"] > 80) & (df["Age"] >= 21)]

print("\nFiltered DataFrame:")
print(filtered_df)

# Grouping
grouped = df.groupby("Department")["Marks"].mean()

print("\nAverage Marks by Department")
print(grouped)

# Sorting
df_sorted = df.sort_values(by="Marks", ascending=False)

print("\nSorted by Marks")
print(df_sorted)

# Boolean Masking
masked_df = df[df["Marks"] > df["Marks"].median()]

print("\nStudents Above Median Marks")
print(masked_df)

# Remove duplicates
df.drop_duplicates(inplace=True)

# Remove missing values
df.dropna(inplace=True)

# Create subset
subset_df = df[["Name", "Marks"]]

print("\nSubset")
print(subset_df)

# Save subset
subset_df.to_csv("filtered_data.csv", index=False)

print("\nfiltered_data.csv created successfully.")

# Statistics
print("\nTotal Marks:", df["Marks"].sum())
print("Average Marks:", df["Marks"].mean())
print("Standard Deviation:", df["Marks"].std())
# Out:
# First 5 rows:
#        Name  Age Department  Marks
# 0    Alice   20        CSE     85
# 1      Bob   21        ECE     78
# 2  Charlie   22         IT     92
# 3    David   20        CSE     88
# 4      Eva   21        EEE     81
#
# Last 5 rows:
#      Name  Age Department  Marks
# 3  David   20        CSE     88
# 4    Eva   21        EEE     81
# 5  Frank   22       MECH     75
# 6  Grace   20        CSE     95
# 7  Henry   21        ECE     80
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      str
#  1   Age         8 non-null      int64
#  2   Department  8 non-null      str
#  3   Marks       8 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 388.0 bytes
#
# Summary Statistics:
#              Age    Marks
# count   8.000000   8.0000
# mean   20.875000  84.2500
# std     0.834523   7.0051
# min    20.000000  75.0000
# 25%    20.000000  79.5000
# 50%    21.000000  83.0000
# 75%    21.250000  89.0000
# max    22.000000  95.0000
#
# New Column:
#       Name  Age Department  Marks  Double_Marks
# 0    Alice   20        CSE     85           170
# 1      Bob   21        ECE     78           156
# 2  Charlie   22         IT     92           184
# 3    David   20        CSE     88           176
# 4      Eva   21        EEE     81           162
# 5    Frank   22       MECH     75           150
# 6    Grace   20        CSE     95           190
# 7    Henry   21        ECE     80           160
#
# Marks + 10
# 0     95
# 1     88
# 2    102
# 3     98
# 4     91
# 5     85
# 6    105
# 7     90
# Name: Marks, dtype: int64
#
# Filtered DataFrame:
#       Name  Age Department  Marks  Double_Marks
# 2  Charlie   22         IT     92           184
# 4      Eva   21        EEE     81           162
#
# Average Marks by Department
# Department
# CSE     89.333333
# ECE     79.000000
# EEE     81.000000
# IT      92.000000
# MECH    75.000000
# Name: Marks, dtype: float64
#
# Sorted by Marks
#       Name  Age Department  Marks  Double_Marks
# 6    Grace   20        CSE     95           190
# 2  Charlie   22         IT     92           184
# 3    David   20        CSE     88           176
# 0    Alice   20        CSE     85           170
# 4      Eva   21        EEE     81           162
# 7    Henry   21        ECE     80           160
# 1      Bob   21        ECE     78           156
# 5    Frank   22       MECH     75           150
#
# Students Above Median Marks
#       Name  Age Department  Marks  Double_Marks
# 0    Alice   20        CSE     85           170
# 2  Charlie   22         IT     92           184
# 3    David   20        CSE     88           176
# 6    Grace   20        CSE     95           190
#
# Subset
#       Name  Marks
# 0    Alice     85
# 1      Bob     78
# 2  Charlie     92
# 3    David     88
# 4      Eva     81
# 5    Frank     75
# 6    Grace     95
# 7    Henry     80
#
# filtered_data.csv created successfully.
#
# Total Marks: 674
# Average Marks: 84.25
# Standard Deviation: 7.00510018282598
